# %%
import os
import pandas as pd
import sklearn

from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# /Users/i574473/Documents/FACCAT/TCC

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
text = ["i love the NLP",
        "NLP is the future",
        "i will learn the NLP"]
vectorizer = TfidfVectorizer()
matrix = vectorizer.fit_transform(text)
count_array = matrix.toarray()
df = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
print(df)
# Out:
#      future        is     learn      love       nlp       the      will
# 0  0.000000  0.000000  0.000000  0.767495  0.453295  0.453295  0.000000
# 1  0.608845  0.608845  0.000000  0.000000  0.359594  0.359594  0.000000
# 2  0.000000  0.000000  0.608845  0.000000  0.359594  0.359594  0.608845

# %%
# data = pd.read_csv('tweets.csv')
# data.head()
# Out:
#                                           Tweet.Text Tweet.CreatedAt  \
# 0  O veículo atravessou uma parede e caiu em cima...      2023-01-04
# 1  Ministro Haddad diz que estuda medidas de até ...      2023-01-04
# 2  Ainda dá tempo de tentar a sorte! https://t.co...      2023-01-04
# 3  Por causa da enorme quantidade de polpa armaze...      2023-01-04
# 4  Trata-se da primeira pesquisa feita no terceir...      2023-01-04
#
#    Tweet.EditHistoryTweetsId  Tweet.InReplyToUserId  \
# 0        1642202665382805507                    NaN
# 1        1642195123403407362                    NaN
# 2        1642187564655452168                    NaN
# 3        1642183789785804805                    NaN
# 4        1642180025410793473                    NaN
#
#    Tweet.ReferencedTweetsType              Tweet.ContextAnnotations.Domain.Id  \
# 0                         NaN                        ;46;47;11;131;131;69;131
# 1                         NaN                            ;10;35;47;131;69;131
# 2                         NaN                                      ;47;69;131
# 3                         NaN                                      ;47;69;131
# 4                         NaN  ;29;38;47;131;131;131;131;131;69;69;131;131;29
#
#                 Tweet.ContextAnnotations.Domain.Name  \
# 0  ;Business Taxonomy;Brand;Sport;Unified Twitter...
# 1  ;Person;Politician;Brand;Unified Twitter Taxon...
# 2      ;Brand;News Vertical;Unified Twitter Taxonomy
# 3      ;Brand;News Vertical;Unified Twitter Taxonomy
# 4  ;Events [Entity Service];Political Race;Brand;...
#
#                   Tweet.ContextAnnotations.Entity.Id  \
# 0  ;1557697289971322880;920731680242991104;706083...
# 1  ;912694884091412481;912694884091412481;9207316...
# 2  ;920731680242991104;840159616101044224;8401596...
# 3  ;920731680242991104;840159616101044224;8401596...
# 4  ;1411038381841084418;1411038381841084418;92073...
#
#                 Tweet.ContextAnnotations.Entity.Name  \
# 0  ;Sports & Fitness Business;Portal g1;Basketbal...
# 1  ;Fernando Haddad;Fernando Haddad;Portal g1;Fer...
# 2                   ;Portal g1;World news;World news
# 3                   ;Portal g1;World news;World news
# 4  ;Brazil General Elections 2022;Brazil General ...
#
#    Tweet.PublicMetrics.RetweetCount  ...  User.Location  \
# 0                                 0  ...         Brasil
# 1                                 3  ...         Brasil
# 2                                 1  ...         Brasil
# 3                                 1  ...         Brasil
# 4                                 1  ...         Brasil
#
#                                 User.ProfileImageURL  User.VerifiedType  \
# 0  https://pbs.twimg.com/profile_images/160493344...           business
# 1  https://pbs.twimg.com/profile_images/160493344...           business
# 2  https://pbs.twimg.com/profile_images/160493344...           business
# 3  https://pbs.twimg.com/profile_images/160493344...           business
# 4  https://pbs.twimg.com/profile_images/160493344...           business
#
#    User.PublicMetrics.FollowersCount User.PublicMetrics.FollowingCount  \
# 0                           14770498                                61
# 1                           14770498                                61
# 2                           14770498                                61
# 3                           14770498                                61
# 4                           14770498                                61
#
#    User.PublicMetrics.TweetCount  User.PublicMetrics.ListedCount  \
# 0                         757981                           19414
# 1                         757981                           19414
# 2                         757981                           19414
# 3                         757981                           19414
# 4                         757981                           19414
#
#                                     User.Description User.Protected  \
# 0  Siga o g1 nas redes sociais:\nhttps://t.co/Z0Q...          False
# 1  Siga o g1 nas redes sociais:\nhttps://t.co/Z0Q...          False
# 2  Siga o g1 nas redes sociais:\nhttps://t.co/Z0Q...          False
# 3  Siga o g1 nas redes sociais:\nhttps://t.co/Z0Q...          False
# 4  Siga o g1 nas redes sociais:\nhttps://t.co/Z0Q...          False
#
#   User.Verified
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 38 columns]
